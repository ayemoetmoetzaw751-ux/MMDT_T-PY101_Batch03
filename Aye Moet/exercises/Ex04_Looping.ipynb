# %% [markdown]
# <a href="https://colab.research.google.com/github/ayemoetmoetzaw751-ux/MMDT_T-PY101_Batch03/blob/main/Aye%20Moet/exercises/Ex04_Looping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The exercises are extracted from A_Practical_Introduction_to_Python_Programming_Heinold.pdf

# %% [markdown]
# Ex 1: Write a program that uses a while loop (not a for loop) to read through a string and print
# the characters of the string one-by-one on separate lines.

# %%
 my_str = "Python Programming"
 i=0
 while i < len(my_str):
  print(my_str[i])
  i += 1
  print()
# Out:
# P
#
# y
#
# t
#
# h
#
# o
#
# n
#
#
#
# P
#
# r
#
# o
#
# g
#
# r
#
# a
#
# m
#
# m
#
# i
#
# n
#
# g

# %% [markdown]
# Ex 2: A good program will make sure that the data its users enter is valid. Write a program that
# asks the user for a weight and converts it from kilograms to pounds. Whenever the user
# enters a weight below 0, the program should tell them that their entry is invalid and then ask
# them again to enter a weight. [Hint: Use a while loop, not an if statement].

# %%
weight= float(input("Enter your weight in Kilogram: "))

while weight <= 0:
  print("Data Entry Mistake!")
  weight = float(input("Enter your weight in Kilogram: "))

weight_p = weight * 2.2
print(f"Your weight is {weight_p} pounds")

print("Done")
# Out:
# Enter your weight in Kilogram: 0
# Data Entry Mistake!
# Enter your weight in Kilogram: -20
# Data Entry Mistake!
# Enter your weight in Kilogram: 80
# Your weight is 176.0 pounds
# Done

# %% [markdown]
# Ex 3: Write a program that allows the user to enter any number of test scores. The user indicates
# they are done by entering in a negative number. Print how many of the scores are A’s (90 or
# above). Also print out the average

# %%
scores= int(input("Enter your test scores: "))
sum = 0
count = 0
grade_A =0
while scores >= 0:
  sum += scores
  count += 1

  if scores >= 90:
    grade_A += 1
  scores = int(input("Enter your test scores: "))

if count>0:
  average = sum / count
print(f"You have {grade_A} times A in your grade")
print(f"Your average score is {average}")
# Out:
# Enter your test scores: 50
# Enter your test scores: 50
# Enter your test scores: 90
# Enter your test scores: 90
# Enter your test scores: 92
# Enter your test scores: 40
# Enter your test scores: -1
# You have 3 times A in your grade
# Your average score is 68.66666666666667

# %% [markdown]
# Ex 4: Write a program that asks the user for a string and a letter. Using a for loop, the
# program should print the index of the first occurrence of that letter and a message if the
# string does not contain the letter.

# %%
string = input("Enter a string: ")
letter = input("Enter a letter: ")

for i in range(len(string)):
  if string[i]== (len(letter)):
    print(f"The first occurence of the {letter} is at index {i}")
    break

else:
  print(f"The letter {letter} is not found in the string")

# %% [markdown]
# Ex 5: Write a program in which you have a list that contains seven integers that can be 0 or 1. Find the first zero entry in the list and change it to a 1. If there are no zero entries, print a message saying so.

# %%
my_list =[4,3,9,0,7,6,8]

for i in range(8):
  if my_list[i]==0:
    my_list[i]= 1
    print("You found your first zero entry")
    print(f"New list is {my_list}")
    break

else:
  print("You didn't found your first zero entry")
# Out:
# You found your first zero entry
# New lis is [4, 3, 9, 1, 7, 6, 8]
