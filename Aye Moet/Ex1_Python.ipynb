# %% [markdown]
# <a href="https://colab.research.google.com/github/ayemoetmoetzaw751-ux/MMDT_T-PY101_Batch03/blob/main/Ex1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# This section introduces the Python Programming uisng Colab. Follow the instructions and complete the exercises.

# %% [markdown]
# # Ex 1 : Check Version

# %% [markdown]
# Using the below cell, Import the required library and check the version of the python in your environment.

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# # Ex2 : Convert Currency.

# %% [markdown]
# Write a program that asks the user for the amount in usd and converts it to British pounds. The exchange rate is from usd to BP is given as 0.82

# %%
usd_amount = input ("Enter the amount in USD: ")
bp_amount = int(usd_amount) *0.82
print("{} usd is equivalent to {} british pound".format(usd_amount, bp_amount))

# %% [markdown]
# # Ex 3: Temperature Converter

# %% [markdown]
# Write a program that convert temperature in Feranhite to celsius.

# %%
tem_Feranhite = input("Enter your temperatute Feranhite: ")
tem_celcius = int(tem_Feranhite)-32 * 9/5
print("{} degree is equal to {} degree Celcius".format(tem_Feranhite, tem_celcius))
# Out:
# Enter your temperatute Feranhite: 100
# 100 degree is equal to 42.4 degree Celcius

# %% [markdown]
# # Ex 4: Daily Maths

# %% [markdown]
# You are working in a retail shop. Write a program that computes the total cost for a customer that bought 3 differnt types of fruits : apple, orange, mango. Ask the user to enter the quantity and price for each type.

# %%
apple_quantity= int(input("Enter your quantity of apples: "))
apple_price = float(input("Price of an apple: "))

orange_quantity = int(input("Enter your quantity of oranges: "))
orange_price = float(input("Price of an orange: "))

mango_quantity = int(input("Enter your quantity of mango: "))
mango_price = float(input("Price of a mango: "))

cost_apple = apple_price * apple_quantity
cost_orange = orange_price * orange_quantity
cost_mango = mango_price * mango_quantity

total_cost = cost_apple + cost_orange + cost_mango
print("Yourtotal_cost is {}".format(total_cost))
# Out:
# Enter your quantity of apples: 1
# Price of an apple: 100
# Enter your quantity of oranges: 1
# Price of an orange: 100
# Enter your quantity of mango: 1
# Price of a mango: 100
# Yourtotal_cost is 300.0

# %% [markdown]
# # Ex 5 : Greeting

# %% [markdown]
# Write a program to greet the customer who provides the user name. Your program should ask the name of the customer and print "Hello + customer name"

# %%
cus_name = input("Enter your customer Name: ")
print("Hello"+ cus_name)
# Out:
# Enter your customer Name: yin
# Helloyin

# %% [markdown]
# # Ex 6: Random Number
# Write a program that generates a random number, x, between 1 and 50, a random number y between 2 and 5, and computes x^y.

# %%
from random import randint
x = randint(1,50)
print('A random number between 1 and 50: ', x)
# Out:
# A random number between 1 and 50:  11

# %% [markdown]
# # Ex 7: Greet many times.
# Write a program that generates a random number between 1 and 10 and prints your name that many times.

# %%
from random import randint
x = randint(1,10)
name = input("Enter your name: ")
print(("Hello" + name)* x)
# Out:
# Enter your name: Aye
# HelloAyeHelloAyeHelloAyeHelloAyeHelloAyeHelloAyeHelloAye

# %% [markdown]
# # Ex 8: Computing.
# Write a program that asks the user to enter two numbers, x and y, and computes |x-y|/(x+y).

# %%
x= int(input("Enter your x value: "))
y= int(input("Enter your y vaule: "))
computes= (x-y)/(x+y)
print(computes)
# Out:
# Enter your x value: 10
# Enter your y vaule: 5
# 0.3333333333333333

# %% [markdown]
# # Ex 9: Computing
#
# Write a program that asks the user for a number of seconds and prints out how many minutes and seconds that is. For instance, 200 seconds is 3 minutes and 20 seconds.

# %%
total_seconds = int(input("Enter the total seconds: "))
minutes = total_seconds // 60
remaining_sec = total_seconds % 60
print("{} seconds is equal to {} minutes and {} seconds.".format(total_seconds, minutes, remaining_sec))
# Out:
# Enter the total seconds: 100
# 100 seconds is equal to 1 minutes and 40 seconds.

# %% [markdown]
# # Ex 10: Using Math Module
#
# Write a program that asks the user for a number and then prints out the sine, cosine, and tangent of that number.

# %%
import math
num = float(input("Enter a number:"))
sine_value = math.sin(num)
print(sine_value)

# %%
import math
num = float(input("Enter a number: "))
sin_value = math.sin(num)
cosine_value = math.cos(num)
tangent_value = math.tan(num)
print("Your {} has those {} sine value, {} cosine value, and {} tangent value".format(num, sin_value, cosine_value, tangent_value))
# Out:
# Enter a number: 3
# Your 3.0 has those 0.1411200080598672 sine value, -0.9899924966004454 cosine value, and -0.1425465430742778 tangent value
